# %% [markdown]
# # Operadores Aritméticos

# %%
# Adição
10 + 2
# Out:
# 12

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
# Multiplicação
10 * 2
# Out:
# 20

# %%
# Divisão
10 / 2
# Out:
# 5.0

# %%
# Divisão inteira
10 // 2
# Out:
# 5

# %%
# Resto da divisão
10 % 2
# Out:
# 0

# %%
# Potenciação
10 ** 2
# Out:
# 100

# %% [markdown]
# # Operadores Relacionais

# %%
# Menor
10 < 2
# Out:
# False

# %%
# Menor ou igual
10 <= 2
# Out:
# False

# %%
# Maior
10 > 2
# Out:
# True

# %%
# Maior ou igual
10 >= 2
# Out:
# True

# %%
# Igual
7 == 7
# Out:
# True

# %%
# Diferente
7 != 7
# Out:
# False

# %% [markdown]
# # Operadores Lógicos

# %% [markdown]
# • And
#
# • Or
#
# • Not

# %% [markdown]
# # Tabela Verdade

# %% [markdown]
# And

# %%
print(10 > 2 and 4 < 6)       # V and V - V
print(10 > 2 and 4 > 6)       # V and F - F
print(10 < 2 and 4 < 6)       # F and V - F
print(10 < 2 and 4 > 6)       # F and F - F
# Out:
# True
# False
# False
# False

# %% [markdown]
# Or

# %%
print(10 > 2 or 4 < 6)       # V or V - V
print(10 > 2 or 4 > 6)       # V or F - V
print(10 < 2 or 4 < 6)       # F or V - V
print(10 < 2 or 4 > 6)       # F or F - F
# Out:
# True
# True
# True
# False

# %% [markdown]
# Not

# %%
not 10 > 2       # V - F
# Out:
# False

# %%
not 10 < 2       # F - V
# Out:
# True

# %% [markdown]
# # Variáveis

# %% [markdown]
# Variáveis estão alocadas em espaços na memória.

# %%
# Nome da variável é "x" que armazena o valor 10 em um espaço na memória.
x = 10

print(x)   # Utilizar a referência no nome atribuido.

# 2 iguais é comparação, 1 igual é atribuição. Nesse caso, quer dizer que o nome da variável "x" vai armazenar na memória esse valor "10"; utiliza-se "print".
# Out:
# 10

# %% [markdown]
# Regras

# %% [markdown]
# **Case Sensitive**
#
# A != a
#
# **Boas Práticas com Variáveis**
#
# > Exemplo: Multiplicação de 2 números
#
# Não usar
# * Multiplicação
# * MultiplicacaoDeDoisNumeros
# * m
#
# Usar
# * multiplicacao
# * mult
# * mult_total (snake_case)
